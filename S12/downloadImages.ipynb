# %% [markdown]
# ## Instructions

# %% [markdown]
# Run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# In Google Chrome press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>j</kbd> on Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>j</kbd> on macOS, and a small window the javascript 'Console' will appear. In Firefox press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>k</kbd> on Windows/Linux or <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>k</kbd> on macOS. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise the window.open() command doesn't work. Then you can run the following commands:
#
# ```javascript
# urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# Google Image downloader.
#
# Drag drop your csv file to th left panel.
#
# Rename as boots.csv etc...

# %%
from fastai.vision import *

# %%
#For eg name = boots will look for boots.csv and download images into boots/
name = 'boots'

# %%
dest = Path(name)
dest.mkdir(exist_ok=True)

# %%
download_images(f'{name}.csv',name,max_workers=0)

# %%
# !zip -r imgs.zip boots/ hardhat/ mask/ vest/
# Out:
#   adding: boots/ (stored 0%)
#   adding: boots/00000176.jpg (deflated 1%)
#   adding: boots/00000240.jpg (deflated 3%)
#   adding: boots/00000197.jpg (deflated 8%)
#   adding: boots/00000253.jpg (deflated 0%)
#   adding: boots/00000251.jpg (deflated 1%)
#   adding: boots/00000134.jpg (deflated 3%)
#   adding: boots/00000094.jpg (deflated 2%)
#   adding: boots/00000172.jpg (deflated 6%)
#   adding: boots/00000072.jpg (deflated 2%)
#   adding: boots/00000047.jpg (deflated 3%)
#   adding: boots/00000224.jpg (deflated 7%)
#   adding: boots/00000235.jpg (deflated 2%)
#   adding: boots/00000079.jpg (deflated 6%)
#   adding: boots/00000133.jpg (deflated 5%)
#   adding: boots/00000118.jpg (deflated 6%)
#   adding: boots/00000259.jpg (deflated 0%)
#   adding: boots/00000214.jpg (deflated 8%)
#   adding: boots/00000265.jpg (deflated 5%)
#   adding: boots/00000319.jpg (deflated 1%)
#   adding: boots/00000203.jpg (deflated 0%)
#   adding: boots/00000062.jpg (deflated 13%)
# ...
